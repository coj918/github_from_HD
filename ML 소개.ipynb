# %% [markdown]
# # 1. 인공지능, 머신러닝, 딥러닝
# -  인공 지능 : 컴퓨터가 인관과 같이 생각할 수 있도록 만드는 기법
# -  머신 러닝 : 데이터 기반 학습을 통한 인공지능을 구현하는 기법
# -  딥러닝 : 머신러닝 기법 중 인공신경망(Artificial Nerral Networks) 기범의 Hidden Layer를 깊게 쌓은 구조를 이용한 학습 기법
#
# <img src="https://www.lgcns.com/wp-content/uploads/2021/11/999597495E744F711D.png" width=600 align='left'>

# %% [markdown]
# #
# # 2. 머신 러닝 특징
# - 명시적인 프로그래밍 없이 '<u>데이터를 이용해서 예측 또는 분류</u>'를 수행하는 알고리즘을 구현하는 기법
# - 머신 러닝의 가장 중요한 부분은 <u>머신러닝 모델이 잘 학습할 수 있도록 적적할 특성(Feature)</u>을 설정하는 것

# %% [markdown]
# #
# # 3. 머신러닝 알고리즘
# - 지도 학습 : 입력 변수(X)와 목적 변수(y) 쌍(X,y)을 이용해 학습하는 방법론
# - 비지도 학습 : 입력 변수(X)만을 이용 데이터의 숨겨진 특징을 학습하는 방법론
# - 강화 학습 : Reward를 제공하는 Environment와 Environment 내에서 행동을 수행하는 Agent와 상호작용을 통해 학습하는 방법론
# <img src="https://mblogthumb-phinf.pstatic.net/MjAyMDAzMjBfNjIg/MDAxNTg0NjgxMzkwNDA3.phXztVskcaZOCMWsWZEbLRUCMFajGyEbS_5umsbJ7nMg.7zJtOoA7QIlRS6upLzUmd_N8U7AF_2iQsS-t7QO7HBwg.PNG.k0sm0s1/untitled.png?type=w800" width=800 align='left'>

# %% [markdown]
# #
# # 4. Training / Validation / Test Data
# - Training Data : 머신 러닝 모델 학습
# - Validation Data : 학습된 모델의 검증 (Over Fitting 방지 및 머신러닝 모델의 Parameter 조정)
# - Test Data : 평가 및 예측

# %%
import mglearn

mglearn.plots.plot_threefold_split()

# %% [markdown]
# # 5. 머신러닝 모델 종류
# - 분류(Classification) : 예측 결과값이 이산값(Discrete Value)인 문제 - Precesion, Recall로 평가
# - 회귀(Regression) : 예측 결과값이 연속값(Continuous Value)인 문제 - R-Squared로 평가
# <img src="https://jesuisjavert.github.io/gallery/post/tensorflow/tensorflow9.png" width=800 align='left'>
